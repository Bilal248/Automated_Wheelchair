# %%
import folium
from folium import Map, PolyLine, Marker
from folium.plugins import MarkerCluster
from folium.utilities import validate_location
import pandas as pd

# %%
df = pd.read_csv('uni7_data.csv')
df
# Out:
#        uid  timeOfFlight   hc   latitude  longitude     speed  datetime  \
# 0    bilal         537.0  0.0  33.980079   9.093752  0.529672  125930.0
# 1    bilal        8191.0  0.0  33.980075   9.093760  0.151864  125932.0
# 2    bilal        8190.0  0.0  33.980075   9.093747  2.381672  125934.0
# 3    bilal        8191.0  0.0  33.980074   9.093735  1.783476  125936.0
# 4    bilal        8191.0  0.0  33.980071   9.093725  1.753844  125938.0
# ..     ...           ...  ...        ...        ...       ...       ...
# 232  bilal        8190.0  0.0  33.980242   9.093794  5.007808  130731.0
# 233  bilal        8190.0  0.0  33.980219   9.093805  4.418872  130733.0
# 234  bilal        8190.0  0.0  33.980199   9.093815  3.635476  130735.0
# 235  bilal        8191.0  0.0  33.980192   9.093817  0.298172  130737.0
# 236  bilal         424.0  0.0  33.980191   9.093817  0.344472  130739.0
#
#         bearing direction
# 0           NaN       NaN
# 1    117.165255     right
# 2    269.136382      left
# 3    262.818962      left
# 4    250.988464      left
# ..          ...       ...
# 232  154.114865  backward
# 233  158.523807  backward
# 234  159.316674  backward
# 235  167.746814  backward
# 236  172.131275  backward
#
# [237 rows x 9 columns]

# %%
# Create a map centered at the mean latitude and longitude
map_center = [df['latitude'].mean(), df['longitude'].mean()]
mymap = folium.Map(location=map_center, zoom_start=15)

# Add markers for each row in the dataframe
for _, row in df.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=f"UID: {row['uid']}<br>Speed: {row['speed']} km/h<br>Direction: {row['direction']}",
    ).add_to(mymap)

# Display the map
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3aaffb0282c882300995425793b58e8b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3aaffb0282c882300995425793b58e8b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3aaffb0282c882300995425793b58e8b = L.map(
#                 &quot;map_3aaffb0282c882300995425793b58e8b&quot;,
#                 {
#                     center: [33.98028273417721, 9.094027445147681],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_229c32e3aa32d406ff642bcf77b27a89 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_229c32e3aa32d406ff642bcf77b27a89.addTo(map_3aaffb0282c882300995425793b58e8b);
#
#
#             var marker_fda0b07afe235694846641d0dd822dd8 = L.marker(
#                 [33.980078666666664, 9.093752166666668],
#                 {
# }
#             ).addTo(map_3aaffb0282c882300995425793b58e8b);
#
#
#         var popup_3b1087eaa127905ca5a4f31416de0f46 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_775488886acb0b18d0e5ef94f7402b2f = $(`&lt;div id=&quot;html_775488886acb0b18d0e5ef94f7402b2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UID: bilal&lt;br&gt;Speed: 0.529672 km/h&lt;br&gt;Direction: nan&lt;/div&gt;`)[0];
#                 popup_3b1087eaa127905ca5a4f31416de0f46.setContent(html_775488886acb0b18d0e5ef94f7402b2f);
#
#
#
#         marker_fda0b07afe235694846641d0dd822dd8.bindPopup(popup_3b1087eaa127905ca5a4f31416de0f46)
#         ;
#
#
#
#
#             var marker_d7a7956b96e0ab84d104e2c46ef741df = L.marker(
#                 [33.98007533333333, 9.09376],
#                 {
# }
#             ).addTo(map_3aaffb0282c882300995425793b58e8b);
#
#
#         var popup_e3018794eff789b9ec5dd860272c0e1e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5db1c708dd6f9b4e04eb3a73961c09c8 = $(`&lt;div id=&quot;html_5db1c708dd6f9b4e04eb3a73961c09c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UID: bilal&lt;br&gt;Speed: 0.151864 km/h&lt;br&gt;Direction: right&lt;/div&gt;`)[0];
#                 popup_e3018794eff789b9ec5dd860272c0e1e.setContent(html_5db1c708dd6f9b4e04eb3a73961c09c8);
#
#
#
#         marker_d7a7956b96e0ab84d104e2c46ef741df.bindPopup(popup_e3018794eff789b9ec5dd860272c0e1e)
#         ;
#
#
#
#
#             var marker_b21f5d34e13f6b7e5f4e089aef69b8e8 = L.marker(
#                 [33.980075166666666, 9.093746666666666],
#                 {
# }
#             ).addTo(map_3aaffb0282c882300995425793b58e8b);
#
#
#         var popup_83ed3bed0365a121bd857cd1092f2a45 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_329432f864f0b60ff31c33a0895aabcc = $(`&lt;div id=&quot;html_329432f864f0b60ff31c33a0895aabcc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UID: bilal&lt;br&gt;Speed: 2.381672 km/h&lt;br&gt;Direction: left&lt;/div&gt;`)[0];
#                 popup_83ed3bed0365a121bd857cd1092f2a45.setContent(html_329432f864f0b60ff31c33a0895aabcc);
#
#
#
#         marker_b21f5d34e13f6b7e5f4e089aef69b8e8.bindPopup(popup_83ed3bed0365a121bd857cd1092f2a45)
#         ;
#
#
#
#
#             var marker_d7593f477db9b0694b747d3926c16020 = L.marker(
#                 [33.980074, 9.0937355],
#                 {
# }
#             ).addTo(map_3aaffb0282c882300995425793b58e8b);
#
#
#         var popup_60bd999c395ce738de4f94b1b6df2619 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1f8e7d63d9fe6661fcb6edd4ae068d8 = $(`&lt;div id=&quot;html_c1f8e7d63d9fe6661fcb6edd4ae068d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UID: bilal&lt;br&gt;Speed: 1.783476 km/h&lt;br&gt;Direction: left&lt;/div&gt;`)[0];
#                 popup_60bd999c395ce738de4f94b1b6df2619.setContent(html_c1f8e7d63d9fe6661fcb6edd4ae068d8);
#
#
#
#         marker_d7593f477db9b0694b747d3926c16020.bindPopup(popup_60bd999c395ce738de4f94b1b6df2619)
#         ;
#
#
#
#
#             var marker_6c8bd593a51dc1727a8f849341e37bc6 = L.marker(
#                 [33.980071, 9.093725],
#                 {
# }
#             ).addTo(map_3aaffb0282c882300995425793b58e8b);
#
#
#         var popup_9d22545481f16a06952892037475d112 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90c179a467ba4369ea9fd3d7d0bcc3ac = $(`&lt;div id=&quot;html_90c179a467ba4369ea9fd3d7d0bcc3ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UID: bilal&lt;br&gt;Speed: 1.753844 km/h&lt;br&gt;Direction: left&lt;/div&gt;`)[0];
#                 popup_9d22545481f16a06952892037475d112.setContent

# %%
# Create a map with bounds adjusted to the coordinates
bounds = [[min(df['latitude']), min(df['longitude'])], [max(df['latitude']), max(df['longitude'])]]
zoomed_map = Map(location=map_center, zoom_start=15)
zoomed_map.fit_bounds(bounds)

# Define coordinates as a list of latitude and longitude pairs
coordinates = df[['latitude', 'longitude']].values.tolist()

# Add a PolyLine to represent the continuous movement
PolyLine(
    locations=coordinates,
    color='blue',
    weight=3,
    opacity=0.8
).add_to(zoomed_map)

# Add clustered markers for each point
marker_cluster = MarkerCluster().add_to(zoomed_map)
for _, row in df.iterrows():
    Marker(
        location=[row['latitude'], row['longitude']],
        popup=f"UID: {row['uid']}<br>Speed: {row['speed']} km/h<br>Direction: {row['direction']}",
    ).add_to(marker_cluster)

# Display the map
zoomed_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_226ff05052d511fa0fbbffd198a21d01 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_226ff05052d511fa0fbbffd198a21d01&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_226ff05052d511fa0fbbffd198a21d01 = L.map(
#                 &quot;map_226ff05052d511fa0fbbffd198a21d01&quot;,
#                 {
#                     center: [33.98028273417721, 9.094027445147681],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6f7f5d489efd240705503afd31152805 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_